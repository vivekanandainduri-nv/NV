# %% [markdown]
# <a href="https://colab.research.google.com/github/vivekanandainduri-nv/NV/blob/main/25BDS0048_exp5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
height = [120, 122, 125, 127, 121, 123, 137, 131, 161, 145, 141, 132]
import pandas as pd
bins = [118, 125, 135, 160, 200]
category = pd.cut(height, bins)
category
# Out:
# [(118, 125], (118, 125], (118, 125], (125, 135], (118, 125], ..., (125, 135], (160, 200], (135, 160], (135, 160], (125, 135]]
# Length: 12
# Categories (4, interval[int64, right]): [(118, 125] < (125, 135] < (135, 160] < (160, 200]]

# %%
pd.value_counts(category)
# Out:
# /tmp/ipykernel_1159/1463743115.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(category)
# (118, 125]    5
# (125, 135]    3
# (135, 160]    3
# (160, 200]    1
# Name: count, dtype: int64

# %%
bin_names = ['Short Height', 'Average height', 'Good Height', 'Taller']
pd.cut(height, bins, labels=bin_names)
# Out:
# ['Short Height', 'Short Height', 'Short Height', 'Average height', 'Short Height', ..., 'Average height', 'Taller', 'Good Height', 'Good Height', 'Average height']
# Length: 12
# Categories (4, object): ['Short Height' < 'Average height' < 'Good Height' < 'Taller']

# %%
import numpy as np
pd.cut(np.random.rand(40), 5, precision=2)
# Out:
# [(0.0081, 0.21], (0.6, 0.8], (0.41, 0.6], (0.0081, 0.21], (0.21, 0.41], ..., (0.21, 0.41], (0.21, 0.41], (0.21, 0.41], (0.8, 1.0], (0.21, 0.41]]
# Length: 40
# Categories (5, interval[float64, right]): [(0.0081, 0.21] < (0.21, 0.41] < (0.41, 0.6] < (0.6, 0.8] <
#                                            (0.8, 1.0]]

# %%
randomNumbers = np.random.rand(2000)
category3 = pd.qcut(randomNumbers, 4)
category3
# Out:
# [(0.759, 1.0], (0.254, 0.51], (0.51, 0.759], (0.254, 0.51], (0.254, 0.51], ..., (-0.0009786, 0.254], (0.759, 1.0], (0.759, 1.0], (-0.0009786, 0.254], (-0.0009786, 0.254]]
# Length: 2000
# Categories (4, interval[float64, right]): [(-0.0009786, 0.254] < (0.254, 0.51] < (0.51, 0.759] <
#                                            (0.759, 1.0]]

# %%
pd.value_counts(category3)
# Out:
# /tmp/ipykernel_1159/647498483.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(category3)
# (-0.0009786, 0.254]    500
# (0.254, 0.51]          500
# (0.51, 0.759]          500
# (0.759, 1.0]           500
# Name: count, dtype: int64

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b3894fd3-3393-4d33-ab44-69a76b083e7d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b3894fd3-3393-4d33-ab44-69a76b083e7d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("fraudTest.csv")
df.head(10)
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
# 5           5   2020-06-21 12:15:37    30407675418785
# 6           6   2020-06-21 12:15:44   213180742685905
# 7           7   2020-06-21 12:15:50  3589289942931264
# 8           8   2020-06-21 12:16:10  3596357274378601
# 9           9   2020-06-21 12:16:11  3546897637165774
#
#                                merchant        category     amt     first  \
# 0                 fraud_Kirlin and Sons   personal_care    2.86      Jeff
# 1                  fraud_Sporer-Keebler   personal_care   29.84    Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness   41.28    Ashley
# ...

# %%
df = pd.read_csv("fraudTest.csv")
Amount = df["amt"]
print(Amount[np.abs(Amount)>1000])
# Out:
# 167       1199.45
# 428       1881.53
# 951       3204.98
# 999       2068.05
# 1398      1420.90
#            ...
# 554526    3304.44
# 554553    1362.77
# 555004    2149.66
# 555229    1309.21
# 555637    1164.37
# Name: amt, Length: 1583, dtype: float64

# %%
outliers = df[np.abs(Amount)>1000]
print(outliers)
# Out:
#         Unnamed: 0 trans_date_trans_time               cc_num  \
# 167            167   2020-06-21 13:08:46     6011109736646996
# 428            428   2020-06-21 14:38:09       38530489946071
# 951            951   2020-06-21 17:40:54  4292743669224718067
# 999            999   2020-06-21 17:55:33     4933461930348832
# 1398          1398   2020-06-21 20:15:59  4956828990005111019
# ...            ...                   ...                  ...
# 554526      554526   2020-12-31 17:06:52     6528911529051375
# 554553      554553   2020-12-31 17:17:41     3582754887089201
# 555004      555004   2020-12-31 19:43:11     4364010865167176
# 555229      555229   2020-12-31 21:08:01       36913587729122
# 555637      555637   2020-12-31 23:30:29     6011109736646996
#
#                                     merchant      category      amt     first  \
# 167                         fraud_Schumm PLC  shopping_net  1199.45   Rebecca
# ...

# %%
population= df["city_pop"]
print(population[np.abs(population)>500000])
# Out:
# 21         525713
# 29        1577385
# 41        1595797
# 57         601723
# 59        2504700
#            ...
# 555625     673342
# 555633    1312922
# 555649    1526206
# 555664    1577385
# 555680    1577385
# Name: city_pop, Length: 28028, dtype: int64

# %%
clean_df = df[df["amt"]<=1000]
print(clean_df.shape)
clean_df.to_csv("clean_data.csv",index = False)
# Out:
# (554136, 23)

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

# %%
data = {
 'Age': [25, 30, 45, 35, 22],
 'Salary': [50000, 64000, 120000, 85000, 1200000] # 1,200,000 is an outlier
}
df = pd.DataFrame(data)
print("Original Data:\n", df, "\n")
# Out:
# Original Data:
#     Age   Salary
# 0   25    50000
# 1   30    64000
# 2   45   120000
# 3   35    85000
# 4   22  1200000

# %%
min_max_scaler = MinMaxScaler()
df_min_max = pd.DataFrame(
 min_max_scaler.fit_transform(df),
 columns=df.columns
)
print("Min-Max Scaled Data:\n", df_min_max, "\n")
# Out:
# Min-Max Scaled Data:
#          Age    Salary
# 0  0.130435  0.000000
# 1  0.347826  0.012174
# 2  1.000000  0.060870
# 3  0.565217  0.030435
# 4  0.000000  1.000000

# %%
standard_scaler = StandardScaler()
df_standard = pd.DataFrame(
 standard_scaler.fit_transform(df),
 columns=df.columns
)
print("Standardized Data:\n", df_standard, "\n")
# Out:
# Standardized Data:
#          Age    Salary
# 0 -0.788742 -0.565609
# 1 -0.172537 -0.534409
# 2  1.676077 -0.409609
# 3  0.443667 -0.487609
# 4 -1.158465  1.997236
